# %% [markdown]
# (sec:conf_search)=
# # Conformational search
# Conformational search aims to identify the possible three-dimensional arrangements of a molecule by exploring its torsional degrees of freedom. For small and rigid molecules, a systematic enumeration of all rotatable bond combinations is feasible and guarantees complete coverage of the conformational space. However, as the number of rotatable bonds grows, the combinatorial explosion of possible conformations makes systematic search computationally intractable for larger and more flexible systems.
#
# For small molecules, VeloxChem provides the `ConformerGenerator` class, which performs a systematic search by enumerating all combinations of rotatable bond angles, followed by MM energy minimization of each generated structure, yielding a ranked list of low-energy conformers.
#
# For larger and more flexible systems, VeloxChem offers an MD-based conformational sampling approach through the `conformational_sampling` method of the `OpenMMDynamics` class. By running a high-temperature MD simulation, the molecule can overcome torsional barriers and broadly explore its conformational space. Snapshots collected along the trajectory are energy-minimized and, optionally, filtered to retain only unique conformers, providing a diverse and representative ensemble of structures.

# %% [markdown]
# (sec:sys_search)=
# ## Systematic Search

# %%
import veloxchem as vlx
molecule = vlx.Molecule.read_smiles(
    "CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)CC3=CC=CC=C3)C(=O)O)C")  
molecule.show(atom_indices=True)
# Out:
# <div id="3dmolviewer_17734148785692253"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17734148785692253" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17734148785692253 = null;
# var warn = document.getElementById("3dmolwarning_17734148785692253");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17734148785692253 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17734148785692253"),{backgroundColor:"white"});
# viewer_17734148785692253.zoomTo();
# 	viewer_17734148785692253.addModel("41\n\nC             -1.432391000000        -2.171883000000        -0.976185000000\nC             -0.741560000000        -0.819676000000        -1.244187000000\nC              0.204285000000        -0.846742000000        -2.489142000000\nN              1.519995000000        -1.079253000000        -1.946829000000\nC              1.778603000000        -1.178384000000        -0.543724000000\nS              0.303732000000        -0.433777000000         0.236248000000\nC              3.004321000000        -0.411182000000        -0.623105000000\nC              2.823085000000        -0.395458000000        -2.109807000000\nO              3.469251000000         0.071361000000        -3.083616000000\nN              2.913763000000         0.936162000000        -0.054780000000\nC              3.011785000000         1.170365000000         1.355924000000\nO              3.350892000000         0.237618000000         2.133773000000\nC              2.637737000000         2.507062000000         1.919158000000\nC              1.140887000000         2.656172000000         1.914649000000\nC              0.376244000000         2.139798000000         2.974338000000\nC             -1.019762000000         2.211791000000         2.935994000000\nC             -1.661753000000         2.790739000000         1.837933000000\nC             -0.909125000000         3.299063000000         0.776190000000\nC              0.486957000000         3.229803000000         0.810460000000\nC             -0.138965000000        -1.869223000000        -3.538012000000\nO              0.398778000000        -3.009684000000        -3.524997000000\nO             -1.092431000000        -1.565230000000        -4.504030000000\nC             -1.805126000000         0.278457000000        -1.392904000000\nH             -0.678369000000        -2.982785000000        -0.886204000000\nH             -2.010010000000        -2.129640000000        -0.027985000000\nH             -2.138495000000        -2.426975000000        -1.795047000000\nH              0.217894000000         0.151239000000        -2.981089000000\nH              1.937422000000        -2.237907000000        -0.243408000000\nH              3.920085000000        -0.959491000000        -0.312714000000\nH              2.749940000000         1.753315000000        -0.686440000000\nH              3.028580000000         2.607652000000         2.955490000000\nH              3.110521000000         3.309535000000         1.312364000000\nH              0.861174000000         1.672718000000         3.822492000000\nH             -1.604074000000         1.811557000000         3.754150000000\nH             -2.742313000000         2.840211000000         1.807461000000\nH             -1.407999000000         3.738125000000        -0.077824000000\nH              1.056581000000         3.611785000000        -0.027189000000\nH             -1.352825000000        -2.244658000000        -5.208805000000\nH             -2.455595000000         0.316352000000        -0.492425000000\nH             -1.322846000000         1.272455000000        -1.510698000000\nH             -2.439990000000         0.084597000000        -2.283985000000\n");
# 	viewer_17734148785692253.addLabel("1",{"position": {"x": -1.432391, "y": -2.171883, "z": -0.976185}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("2",{"position": {"x": -0.74156, "y": -0.819676, "z": -1.244187}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("3",{"position": {"x": 0.204285, "y": -0.846742, "z": -2.4891419999999997}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("4",{"position": {"x": 1.519995, "y": -1.079253, "z": -1.946829}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("5",{"position": {"x": 1.778603, "y": -1.178384, "z": -0.543724}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("6",{"position": {"x": 0.303732, "y": -0.43377699999999997, "z": 0.236248}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("7",{"position": {"x": 3.004321, "y": -0.411182, "z": -0.623105}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("8",{"position": {"x": 2.823085, "y": -0.395458, "z": -2.109807}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("9",{"position": {"x": 3.469251, "y": 0.071361, "z": -3.083616}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("10",{"position": {"x": 2.913763, "y": 0.936162, "z": -0.05478}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("11",{"position": {"x": 3.011785, "y": 1.170365, "z": 1.355924}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("12",{"position": {"x": 3.3508919999999995, "y": 0.23761799999999997, "z": 2.133773}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("13",{"position": {"x": 2.637737, "y": 2.507062, "z": 1.919158}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("14",{"position": {"x": 1.140887, "y": 2.656172, "z": 1.914649}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("15",{"position": {"x": 0.376244, "y": 2.1397979999999994, "z": 2.9743379999999995}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("16",{"position": {"x": -1.019762, "y": 2.211791, "z": 2.935994}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17734148785692253.addLabel("17",{"position": {"x": -1.6617

# %% [markdown]
# The `ConformerGenerator` class can generate all possible conformations and minimize them with MM.

# %%
conf = vlx.ConformerGenerator()
conformers_dict = conf.generate(molecule)
# Out:
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Hartree-Fock
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -1421.688988650876 a.u. Time: 6.93 sec.
#
#
#                Iter. | Hartree-Fock Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1     -1422.137288277230    0.0000000000      0.34521978      0.01076056      0.00000000
#                   2     -1422.150883591308   -0.0135953141      0.13852741      0.00681249      0.20136332
#                   3     -1422.152745632243   -0.0018620409      0.04740488      0.00180172      0.06165418
#                   4     -1422.152996081397   -0.0002504492      0.01260392      0.00054387      0.01689306
#                   5     -1422.153019458864   -0.0000233775      0.00330181      0.00013092      0.00707158
#                   6     -1422.153021719078   -0.0000022602      0.00122057      0.00004605      0.00240151
#                   7     -1422.153022066735   -0.0000003477      0.00047879      0.00001849      0.00087143
#                   8     -1422.153022148479   -0.0000000817      0.00023057      0.00000921      0.00044335
#                   9     -1422.153022168926   -0.0000000204      0.00011633      0.00000530      0.00018288
#                  10     -1422.153022175781   -0.0000000069      0.00004509      0.00000228      0.00012211
#                  11     -1422.153022176969   -0.0000000012      0.00001651      0.00000108      0.00005383
#                  12     -1422.153022177113   -0.0000000001      0.00000731      0.00000045      0.00001859
#                  13     -1422.153022177136   -0.0000000000      0.00000335      0.00000021      0.00000667
#                  14     -1422.153022177142   -0.0000000000      0.00000149      0.00000008      0.00000351
#                  15     -1422.153022177142    0.0000000000      0.00000051      0.00000002      0.00000156
#
#                *** SCF converged in 15 iterations. Time: 47.54 sec.
#
#                Spin-Restricted Hartree-Fock:
#                -----------------------------
#                Total Energy                       :    -1422.1530221771 a.u.
#                Electronic Energy                  :    -3621.1465081340 a.u.
#                Nuclear Repulsion Energy           :     2198.9934859569 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000005144 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1
#                Magnetic Quantum Number (M_S) :  0.0
#
#
#                                                 RESP Charges Driver Setup
#                                                ===========================
#
#                                          Number of Conformers         :  1
#                                          Number of Layers             :  4
#                                          Points per Square Angstrom   :  1.0
#                                          Total Number of Grid Points  :  1558
#
#
#                                                      First Stage Fit
#                                                     -----------------
#
#                                          Restraint Strength           :  0.0005
#                                          Restrained Hydrogens         :  No
#                                          Max. Number of Iterations    :  50
#                                          Convergence Threshold (a.u.) :  1e-06
#
#                                       *** Charge fitting converged in 18 iterations.
#
#                                         No. | Atom |  Constraints | Charges (a.u.)
#                                        --------------------------------------------
#                                           1     C                     -0.421498
#                                           2     C                      0.121940
#                                           3     C                      0.138663
#                                           4     N                     -0.363465
#                                           5     C                      0.092371
#                                           6     S                     -0.159185
#                                           7     C                      0.006371
#                                           8     C                      0.517590
#                                           9     O                     -0.497452
#                                          10     N                     -0.543808
#                                          11     C                      0.503487
#                                          12     O                     -0.511901
#                                          13     C                     -0.042826
#                                          14     C                     -0.007142
#                                          15     C                     -0.118685
#                                          16     C                     -0.167398
#                                          17     C                     -0.093537
#                                          18     C                     -0.188953
#                                          19     C                     -0.146599
#                                          20     C                      0.707625
#                                          21     O                     -0.567478
#                                          22     O                     -0.699712
#                                          23     C                     -0.262930
#                                          24     H                      0.129922
#                                          25     H                      0.124473
#                                          26     H                      0.134567
#                                          27     H                      0.115236
#                                          28     H                      0.102718
#                                          29     H                      0.149997
#                                          30     H                      0.341205
#                                          31     H                      0.077801
#                                          32     H                      0.047531
#                                          33     H                      0.149742
#                                          34     H                      0.150254
#                                          35     H                      0.128339
#                                          36     H                      0.153065
#                                          37     H                      0.140551
#                                          38     H                      0.493416
#                                          39     H                      0.134338
#                                          40     H                      0.060715
#                                          41     H                      0.070654
#                                        --------------------------------------------
#                                                Total Charge  :  0.000000
#
#                                                        Fit Quality
#                                                       -------------
#                                        Relative Root-Mean-Square Error  :  0.093304
#
#
#                                                      Second Stage Fit
#                                                     ------------------
#
#                                          Restraint Strength           :  0.001
#                                          Restrained Hydrogens         :  No
#                                          Max. Number of Iterations    :  50
#                                          Convergence Threshold (a.u.) :  1e-06
#
#                                       *** Charge fitting converged in 16 iterations.
#
#                                     No. | Atom | Frozen | Constraints | Charges (a.u.)
#                                    ----------------------------------------------------
#                                       1     C       No                    -0.375765
#                                       2     C      Yes                     0.121940
#                                       3     C      Yes                     0.138663
#                                       4     N      Yes                    -0.363465
#                                       5     C      Yes                     0.092371
#                                       6     S      Yes                    -0.159185
#                                       7     C      Yes                     0.006371
#                                       8     C      Yes                     0.517590
#                                       9     O      Yes                    -0.497452
#                                      10     N      Yes                    -0.543808
#                                      11     C      Yes                     0.503487
#                                      12     O      Yes                    -0.511901
#                                      13     C       No                    -0.011964
#                                      14     C      Yes                    -0.007142
#                                      15     C      Yes                    -0.118685
#                                      16     C      Yes                    -0.167398
#                                      17     C      Yes                    -0.093537
#                                      18     C      Yes                    -0.188953
#                                      19     C      Yes                    -0.146599
#                                      20     C      Yes                     0.707625
#                                      21     O      Yes                    -0.567478
#                                      22     O      Yes                    -0.699712
#                                      23     C       No                    -0.502990
#                                      24     H       No                     0.126432
#                                      25     H       No         24          0.126432
#                                      26     H       No         25          0.126432
#                                      27     H      Yes                     0.115236
#                                      28     H      Yes                     0.102718
#                                      29     H      Yes                     0.149997
#                                      30     H      Yes                     0.341205
#                                      31     H       No                     0.050417
#                                      32     H       No         31          0.050417
#                                      33     H      Yes                     0.149742
#                                      34     H      Yes                     0.150254
#                                      35     H      Yes                     0.128339
#                                      36     H      Yes                     0.153065
#                                      37     H      Yes                     0.140551
#                                      38     H      Yes                     0.493416
#                                      39     H       No                     0.154445
#                                      40     H       No         39          0.154445
#                                      41     H       No         40          0.154445
#                                    ----------------------------------------------------
#                                                Total Charge  :  0.000000
#
#                                                        Fit Quality
#                                                       -------------
#                                        Relative Root-Mean-Square Error  :  0.112710
#
#                                        Reference:
#                                        J. Phys. Chem. 1993, 97, 10269-10280.
#
# * Info * 36 conformers will be generated.
# * Info * 36 conformers generated in 0.31 sec
# * Info * Energy minimization of 36 conformers took 1.37 sec
# * Info * Global minimum energy: -96.885 kJ/mol
# * Info * 9 conformers remain after removal of duplicate conformers.
# * Info * Total time spent in generating conformers: 57.36 sec

# %% [markdown]
# The lowest conformer can be displayed

# %%
conf.show_global_minimum()
# Out:
# Global minimum conformer with energy -96.885 kJ/mol
# <div id="3dmolviewer_17734149376317725"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17734149376317725" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17734149376317725 = null;
# var warn = document.getElementById("3dmolwarning_17734149376317725");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17734149376317725 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17734149376317725"),{backgroundColor:"white"});
# viewer_17734149376317725.zoomTo();
#          25, 1157-1174.
#
# * Info * Updated bond length 10-14 (cc-ss) to 0.169 nm
# * Info * Updated bond length 13-14 (cc-ss) to 0.168 nm
# * Info * Updated bond length 36-37 (os-c3) to 0.138 nm
# * Info * Updated bond length 43-44 (os-c3) to 0.138 nm
# * Info * Updated bond length 51-57 (ca-cc) to 0.151 nm
# * Info * Updated bond length 57-61 (cc-ss) to 0.169 nm
# * Info * Updated bond length 60-61 (cd-ss) to 0.168 nm
# * Info * Updated bond length 60-106 (cd-ca) to 0.151 nm
# * Info * Updated bond length 84-85 (os-c3) to 0.138 nm
# * Info * Updated bond length 91-92 (os-c3) to 0.138 nm
# * Info * Updated bond length 103-110 (ca-cc) to 0.151 nm
# * Info * Updated bond length 110-114 (cc-ss) to 0.169 nm
# * Info * Updated bond length 113-114 (cc-ss) to 0.169 nm
# * Info * Updated bond length 113-154 (cc-ca) to 0.151 nm
# * Info * Updated bond length 136-137 (os-c3) to 0.138 nm
# * Info * Updated bond length 143-144 (os-c3) to 0.138 nm
# * Info * Updated bond length 151-157 (ca-cc) to 0.151 nm
# * Info * Updated bond length 157-161 (cc-ss) to 0.169 nm
# * Info * Updated bond length 160-161 (cc-ss) to 0.169 nm
# * Info * Updated bond length 160-204 (cc-ca) to 0.151 nm
# * Info * Updated bond length 184-185 (os-c3) to 0.138 nm
# * Info * Updated bond length 191-192 (os-c3) to 0.138 nm
# * Info * Updated bond length 201-208 (ca-cc) to 0.151 nm
# * Info * Updated bond length 208-212 (cc-ss) to 0.169 nm
# * Info * Updated bond length 211-212 (cc-ss) to 0.169 nm
# * Info * Updated bond length 211-252 (cc-ca) to 0.151 nm
# * Info * Updated bond length 234-235 (os-c3) to 0.138 nm
# * Info * Updated bond length 241-242 (os-c3) to 0.138 nm
# * Info * Updated bond length 249-255 (ca-cc) to 0.151 nm
# * Info * Updated bond length 255-259 (cc-ss) to 0.169 nm
# * Info * Updated bond length 258-259 (cc-ss) to 0.169 nm
# * Info * Updated bond length 258-304 (cc-ca) to 0.151 nm
# * Info * Updated bond length 282-283 (os-c3) to 0.138 nm
# * Info * Updated bond length 289-290 (os-c3) to 0.138 nm
# * Info * Updated bond length 301-308 (ca-cc) to 0.151 nm
# * Info * Updated bond length 308-312 (cc-ss) to 0.169 nm
# * Info * Updated bond length 311-312 (cc-ss) to 0.168 nm
# * Info * Updated bond length 334-335 (os-c3) to 0.138 nm
# * Info * Updated bond length 341-342 (os-c3) to 0.138 nm
# * Info * Updated bond length 355-359 (cc-ss) to 0.169 nm
# * Info * Updated bond length 358-359 (cd-ss) to 0.168 nm
# * Info * Updated bond length 382-383 (os-c3) to 0.138 nm
# * Info * Updated bond length 389-390 (os-c3) to 0.138 nm
# * Info * Updated bond angle 3-10-11 (ca-cc-cd) to 129.147 deg
# * Info * Updated bond angle 12-13-54 (cd-cc-ca) to 126.821 deg
# * Info * Updated bond angle 51-57-58 (ca-cc-cd) to 129.494 deg
# * Info * Updated bond angle 59-60-61 (cd-cd-ss) to 105.976 deg
# * Info * Updated bond angle 59-60-106 (cd-cd-ca) to 127.140 deg
# * Info * Updated bond angle 103-110-111 (ca-cc-cd) to 129.577 deg
# * Info * Updated bond angle 112-113-154 (cd-cc-ca) to 127.147 deg
# * Info * Updated bond angle 151-157-158 (ca-cc-cd) to 129.113 deg
# * Info * Updated bond angle 159-160-204 (cd-cc-ca) to 126.734 deg
# * Info * Updated bond angle 201-208-209 (ca-cc-cd) to 128.625 deg
# * Info * Updated bond angle 210-211-252 (cd-cc-ca) to 126.063 deg
# * Info * Updated bond angle 249-255-256 (ca-cc-cd) to 128.947 deg
# * Info * Updated bond angle 257-258-304 (cd-cc-ca) to 126.537 deg
# * Info * Updated bond angle 301-308-309 (ca-cc-cd) to 129.285 deg
# * Info * Updated bond angle 310-311-352 (cd-cc-ca) to 126.759 deg
# * Info * Updated bond angle 349-355-356 (ca-cc-cc) to 128.976 deg
# * Info * Updated bond angle 356-355-359 (cc-cc-ss) to 106.576 deg
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cp is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cq is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cp is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cq is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cp is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cq is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cp is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cq is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cp is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cq is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cp is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cq is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cp is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cq is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cp is not available.
# ***********
# ***********
# * Warning * MMForceFieldGenerator: dihedral ca-nb-cq-cq is not available.
# ***********
# * Info * System parameters written to tq-polymer_system.xml
# * Info * System coordinates written to tq-polymer_system.pdb

# %% [markdown]
# Once a force field [has been derived](#sec:mm-ff-gen) with the `MMForceFieldGenerator` and the system [has been initialized](#sec:MM-init) with the `OpenMMDynamics` class; the `conformational_sampling` function can be used to extract conformers from the MD simulation at high temperature. The user can define a number of snapshots that will be optimized and save. In addition, those snapshots can be filtered to avoid that the same conformer is present multiple timess by using the option unique_conformers.

# %%
conformers_dict = opm_dyn.conformational_sampling(
                                ensemble='NVT', 
                                temperature=1000, 
                                timestep=2.0, 
                                nsteps=100000, 
                                snapshots=500,
                                unique_conformers=True,
                                qm_driver=None,
                                basis=None,
                                constraints=None)
# Out:
# * Info * Minimized energy: 1652.519479751587
# * Info * Saved coordinates for step 200
# * Info * Minimized energy: 1665.202268898487
# * Info * Saved coordinates for step 400
# * Info * Minimized energy: 1704.3299006223679
# * Info * Saved coordinates for step 600
# * Info * Minimized energy: 1687.5876556038857
# * Info * Saved coordinates for step 800
# * Info * Minimized energy: 1712.4535496532917
# * Info * Saved coordinates for step 1000
# * Info * Minimized energy: 1694.2515242099762
# * Info * Saved coordinates for step 1200
# * Info * Minimized energy: 1691.710554778576
# * Info * Saved coordinates for step 1400
# * Info * Minimized energy: 1699.312300503254
# * Info * Saved coordinates for step 1600
# * Info * Minimized energy: 1720.0025205612183
# * Info * Saved coordinates for step 1800
# * Info * Minimized energy: 1699.2965200543404
# * Info * Saved coordinates for step 2000
# * Info * Minimized energy: 1728.4674746394157
# * Info * Saved coordinates for step 2200
# * Info * Minimized energy: 1744.065479695797
# * Info * Saved coordinates for step 2400
# * Info * Minimized energy: 1707.2701814174652
# * Info * Saved coordinates for step 2600
# * Info * Minimized energy: 1725.3512070775032
# * Info * Saved coordinates for step 2800
# * Info * Minimized energy: 1664.8007645606995
# * Info * Saved coordinates for step 3000
# * Info * Minimized energy: 1701.3290429115295
# * Info * Saved coordinates for step 3200
# * Info * Minimized energy: 1643.3138043880463
# * Info * Saved coordinates for step 3400
# * Info * Minimized energy: 1669.0694264173508
# * Info * Saved coordinates for step 3600
# * Info * Minimized energy: 1659.9537135362625
# * Info * Saved coordinates for step 3800
# * Info * Minimized energy: 1655.6384905576706
# * Info * Saved coordinates for step 4000
# * Info * Minimized energy: 1653.9102883338928
# * Info * Saved coordinates for step 4200
# * Info * Minimized energy: 1684.5735810995102
# * Info * Saved coordinates for step 4400
# * Info * Minimized energy: 1674.4345049262047
# * Info * Saved coordinates for step 4600
# * Info * Minimized energy: 1700.9961936473846
# * Info * Saved coordinates for step 4800
# * Info * Minimized energy: 1704.8829264044762
# * Info * Saved coordinates for step 5000
# * Info * Minimized energy: 1706.9741262197495
# * Info * Saved coordinates for step 5200
# * Info * Minimized energy: 1699.6253371238708
# * Info * Saved coordinates for step 5400
# * Info * Minimized energy: 1680.4691813588142
# * Info * Saved coordinates for step 5600
# * Info * Minimized energy: 1677.6652304828167
# * Info * Saved coordinates for step 5800
# * Info * Minimized energy: 1696.1981028616428
# * Info * Saved coordinates for step 6000
# * Info * Minimized energy: 1689.5409828722477
# * Info * Saved coordinates for step 6200
# * Info * Minimized energy: 1681.2814609110355
# * Info * Saved coordinates for step 6400
# * Info * Minimized energy: 1651.9727676808834
# * Info * Saved coordinates for step 6600
# * Info * Minimized energy: 1686.2646807432175
# * Info * Saved coordinates for step 6800
# * Info * Minimized energy: 1644.3939453959465
# * Info * Saved coordinates for step 7000
# * Info * Minimized energy: 1637.3287129998207
# * Info * Saved coordinates for step 7200
# * Info * Minimized energy: 1679.9254457354546
# * Info * Saved coordinates for step 7400
# * Info * Minimized energy: 1609.626150071621
# * Info * Saved coordinates for step 7600
# * Info * Minimized energy: 1640.909385085106
# * Info * Saved coordinates for step 7800
# * Info * Minimized energy: 1635.6808195710182
# * Info * Saved coordinates for step 8000
# * Info * Minimized energy: 1618.3976584076881
# * Info * Saved coordinates for step 8200
# * Info * Minimized energy: 1657.5140321850777
# * Info * Saved coordinates for step 8400
# * Info * Minimized energy: 1609.096551477909
# * Info * Saved coordinates for step 8600
# * Info * Minimized energy: 1648.583098590374
# * Info * Saved coordinates for step 8800
# * Info * Minimized energy: 1630.9204729497433
# * Info * Saved coordinates for step 9000
# * Info * Minimized energy: 1640.2534338831902
# * Info * Saved coordinates for step 9200
# * Info * Minimized energy: 1624.2767887115479
# * Info * Saved coordinates for step 9400
# * Info * Minimized energy: 1649.715049147606
# * Info * Saved coordinates for step 9600
# * Info * Minimized energy: 1643.2279670238495
# * Info * Saved coordinates for step 9800
# * Info * Minimized energy: 1692.1046987771988
# * Info * Saved coordinates for step 10000
# * Info * Minimized energy: 1684.608769774437
# * Info * Saved coordinates for step 10200
# * Info * Minimized energy: 1664.4848421514034
# * Info * Saved coordinates for step 10400
# * Info * Minimized energy: 1655.6460538506508
# * Info * Saved coordinates for step 10600
# * Info * Minimized energy: 1659.4291503727436
# * Info * Saved coordinates for step 10800
# * Info * Minimized energy: 1701.4533559679985
# * Info * Saved coordinates for step 11000
# * Info * Minimized energy: 1672.5815684199333
# * Info * Saved coordinates for step 11200
# * Info * Minimized energy: 1680.0878310203552
# * Info * Saved coordinates for step 11400
# * Info * Minimized energy: 1682.2828733623028
# * Info * Saved coordinates for step 11600
# * Info * Minimized energy: 1676.3434979617596
# * Info * Saved coordinates for step 11800
# * Info * Minimized energy: 1668.5268779098988
# * Info * Saved coordinates for step 12000
# * Info * Minimized energy: 1662.3323314487934
# * Info * Saved coordinates for step 12200
# * Info * Minimized energy: 1664.1425017118454
# * Info * Saved coordinates for step 12400
# * Info * Minimized energy: 1662.886067211628
# * Info * Saved coordinates for step 12600
# * Info * Minimized energy: 1746.3991726636887
# * Info * Saved coordinates for step 12800
# * Info * Minimized energy: 1686.6569061279297
# * Info * Saved coordinates for step 13000
# * Info * Minimized energy: 1696.8386776447296
# * Info * Saved coordinates for step 13200
# * Info * Minimized energy: 1704.545520722866
# * Info * Saved coordinates for step 13400
# * Info * Minimized energy: 1699.8787138462067
# * Info * Saved coordinates for step 13600
# * Info * Minimized energy: 1701.319357931614
# * Info * Saved coordinates for step 13800
# * Info * Minimized energy: 1711.9503685235977
# * Info * Saved coordinates for step 14000
# * Info * Minimized energy: 1699.5601477622986
# * Info * Saved coordinates for step 14200
# * Info * Minimized energy: 1690.4585292935371
# * Info * Saved coordinates for step 14400
# * Info * Minimized energy: 1677.06594145298
# * Info * Saved coordinates for step 14600
# * Info * Minimized energy: 1660.522009268403
# * Info * Saved coordinates for step 14800
# * Info * Minimized energy: 1657.0584095716476
# * Info * Saved coordinates for step 15000
# * Info * Minimized energy: 1673.2568932771683
# * Info * Saved coordinates for step 15200
# * Info * Minimized energy: 1675.2976828366518
# * Info * Saved coordinates for step 15400
# * Info * Minimized energy: 1697.8038520216942
# * Info * Saved coordinates for step 15600
# * Info * Minimized energy: 1678.1594634056091
# * Info * Saved coordinates for step 15800
# * Info * Minimized energy: 1676.0993568897247
# * Info * Saved coordinates for step 16000
# * Info * Minimized energy: 1675.0462568998337
# * Info * Saved coordinates for step 16200
# * Info * Minimized energy: 1657.1192137300968
# * Info * Saved coordinates for step 16400
# * Info * Minimized energy: 1683.5505354255438
# * Info * Saved coordinates for step 16600
# * Info * Minimized energy: 1692.4016361832619
# * Info * Saved coordinates for step 16800
# * Info * Minimized energy: 1696.6549592018127
# * Info * Saved coordinates for step 17000
# * Info * Minimized energy: 1726.1317913234234
# * Info * Saved coordinates for step 17200
# * Info * Minimized energy: 1710.11704236269
# * Info * Saved coordinates for step 17400
# * Info * Minimized energy: 1710.2078562676907
# * Info * Saved coordinates for step 17600
# * Info * Minimized energy: 1709.1292527914047
# * Info * Saved coordinates for step 17800
# * Info * Minimized energy: 1685.4419323951006
# * Info * Saved coordinates for step 18000
# * Info * Minimized energy: 1700.6818700134754
# * Info * Saved coordinates for step 18200
# * Info * Minimized energy: 1690.4554256796837
# * Info * Saved coordinates for step 18400
# * Info * Minimized energy: 1718.2697108387947
# * Info * Saved coordinates for step 18600
# * Info * Minimized energy: 1683.5944452881813
# * Info * Saved coordinates for step 18800
# * Info * Minimized energy: 1701.7359602451324
# * Info * Saved coordinates for step 19000
# * Info * Minimized energy: 1736.6036988794804
# * Info * Saved coordinates for step 19200
# * Info * Minimized energy: 1728.5668051540852
# * Info * Saved coordinates for step 19400
# * Info * Minimized energy: 1670.8947377800941
# * Info * Saved coordinates for step 19600
# * Info * Minimized energy: 1703.6372301578522
# * Info * Saved coordinates for step 19800
# * Info * Minimized energy: 1725.4246835112572
# * Info * Saved coordinates for step 20000
# * Info * Minimized energy: 1718.0123945474625
# * Info * Saved coordinates for step 20200
# * Info * Minimized energy: 1700.2924118638039
# * Info * Saved coordinates for step 20400
# * Info * Minimized energy: 1732.027406603098
# * Info * Saved coordinates for step 20600
# * Info * Minimized energy: 1700.429241269827
# * Info * Saved coordinates for step 20800
# * Info * Minimized energy: 1699.4511661231518
# * Info * Saved coordinates for step 21000
# * Info * Minimized energy: 1709.247181236744
# * Info * Saved coordinates for step 21200
# * Info * Minimized energy: 1694.6056524515152
# * Info * Saved coordinates for step 21400
# * Info * Minimized energy: 1685.4507041573524
# * Info * Saved coordinates for step 21600
# * Info * Minimized energy: 1731.4360711276531
# * Info * Saved coordinates for step 21800
# * Info * Minimized energy: 1683.514085650444
# * Info * Saved coordinates for step 22000
# * Info * Minimized energy: 1691.9118754565716
# * Info * Saved coordinates for step 22200
# * Info * Minimized energy: 1674.4645510315895
# * Info * Saved coordinates for step 22400
# * Info * Minimized energy: 1692.496615767479
# * Info * Saved coordinates for step 22600
# * Info * Minimized energy: 1688.1674928069115
# * Info * Saved coordinates for step 22800
# * Info * Minimized energy: 1682.1264434456825
# * Info * Saved coordinates for step 23000
# * Info * Minimized energy: 1683.660961508751
# * Info * Saved coordinates for step 23200
# * Info * Minimized energy: 1719.3525700569153
# * Info * Saved coordinates for step 23400
# * Info * Minimized energy: 1709.9905819892883
# * Info * Saved coordinates for step 23600
# * Info * Minimized energy: 1688.4839729070663
# * Info * Saved coordinates for step 23800
# * Info * Minimized energy: 1745.1325727701187
# * Info * Saved coordinates for step 24000
# * Info * Minimized energy: 1743.0696623325348
# * Info * Saved coordinates for step 24200
# * Info * Minimized energy: 1750.2302979826927
# * Info * Saved coordinates for step 24400
# * Info * Minimized energy: 1744.3462828993797
# * Info * Saved coordinates for step 24600
# * Info * Minimized energy: 1741.8064453601837
# * Info * Saved coordinates for step 24800
# * Info * Minimized energy: 1739.2032471895218
# * Info * Saved coordinates for step 25000
# * Info * Minimized energy: 1745.3009694814682
# * Info * Saved coordinates for step 25200
# * Info * Minimized energy: 1733.4490084648132
# * Info * Saved coordinates for step 25400
# * Info * Minimized energy: 1746.204572558403
# * Info * Saved coordinates for step 25600
# * Info * Minimized energy: 1663.8089507222176
# * Info * Saved coordinates for step 25800
# * Info * Minimized energy: 1640.8193541765213
# * Info * Saved coordinates for step 26000
# * Info * Minimized energy: 1651.5715470314026
# * Info * Saved coordinates for step 26200
# * Info * Minimized energy: 1653.0557301044464
# * Info * Saved coordinates for step 26400
# * Info * Minimized energy: 1680.0342066586018
# * Info * Saved coordinates for step 26600
# * Info * Minimized energy: 1700.524407863617
# * Info * Saved coordinates for step 26800
# * Info * Minimized energy: 1698.7113647460938
# * Info * Saved coordinates for step 27000
# * Info * Minimized energy: 1659.5748417675495
# * Info * Saved coordinates for step 27200
# * Info * Minimized energy: 1686.6752935424447
# * Info * Saved coordinates for step 27400
# * Info * Minimized energy: 1631.1795259565115
# * Info * Saved coordinates for step 27600
# * Info * Minimized energy: 1625.3649092018604
# * Info * Saved coordinates for step 27800
# * Info * Minimized energy: 1622.4104761779308
# * Info * Saved coordinates for step 28000
# * Info * Minimized energy: 1654.6421470046043
# * Info * Saved coordinates for step 28200
# * Info * Minimized energy: 1619.5582477152348
# * Info * Saved coordinates for step 28400
# * Info * Minimized energy: 1616.8259639143944
# * Info * Saved coordinates for step 28600
# * Info * Minimized energy: 1669.825501024723
# * Info * Saved coordinates for step 28800
# * Info * Minimized energy: 1685.5552546977997
# * Info * Saved coordinates for step 29000
# * Info * Minimized energy: 1680.6964117586613
# * Info * Saved coordinates for step 29200
# * Info * Minimized energy: 1702.3255310058594
# * Info * Saved coordinates for step 29400
# * Info * Minimized energy: 1682.399295449257
# * Info * Saved coordinates for step 29600
# * Info * Minimized energy: 1707.960211277008
# * Info * Saved coordinates for step 29800
# * Info * Minimized energy: 1689.3415873646736
# * Info * Saved coordinates for step 30000
# * Info * Minimized energy: 1720.8129621744156
# * Info * Saved coordinates for step 30200
# * Info * Minimized energy: 1707.3118589520454
# * Info * Saved coordinates for step 30400
# * Info * Minimized energy: 1697.0512202978134
# * Info * Saved coordinates for step 30600
# * Info * Minimized energy: 1669.1828097105026
# * Info * Saved coordinates for step 30800
# * Info * Minimized energy: 1679.5893332362175
# * Info * Saved coordinates for step 31000
# * Info * Minimized energy: 1682.3793233036995
# * Info * Saved coordinates for step 31200
# * Info * Minimized energy: 1681.9400026202202
# * Info * Saved coordinates for step 31400
# * Info * Minimized energy: 1636.614893734455
# * Info * Saved coordinates for step 31600
# * Info * Minimized energy: 1658.9558490514755
# * Info * Saved coordinates for step 31800
# * Info * Minimized energy: 1673.9521681293845
# * Info * Saved coordinates for step 32000
# * Info * Minimized energy: 1683.3323159515858
# * Info * Saved coordinates for step 32200
# * Info * Minimized energy: 1667.487584233284
# * Info * Saved coordinates for step 32400
# * Info * Minimized energy: 1681.5881145000458
# * Info * Saved coordinates for step 32600
# * Info * Minimized energy: 1659.9769133329391
# * Info * Saved coordinates for step 32800
# * Info * Minimized energy: 1731.2233895659447
# * Info * Saved coordinates for step 33000
# * Info * Minimized energy: 1714.975441813469
# * Info * Saved coordinates for step 33200
# * Info * Minimized energy: 1764.5676757097244
# * Info * Saved coordinates for step 33400
# * Info * Minimized energy: 1734.3877938985825
# * Info * Saved coordinates for step 33600
# * Info * Minimized energy: 1727.6337056159973
# * Info * Saved coordinates for step 33800
# * Info * Minimized energy: 1664.0397191047668
# * Info * Saved coordinates for step 34000
# * Info * Minimized energy: 1682.515762835741
# * Info * Saved coordinates for step 34200
# * Info * Minimized energy: 1688.4868807792664
# * Info * Saved coordinates for step 34400
# * Info * Minimized energy: 1692.3423596322536
# * Info * Saved coordinates for step 34600
# * Info * Minimized energy: 1676.556672334671
# * Info * Saved coordinates for step 34800
# * Info * Minimized energy: 1682.1091638207436
# * Info * Saved coordinates for step 35000
# * Info * Minimized energy: 1696.9233548045158
# * Info * Saved coordinates for step 35200
# * Info * Minimized energy: 1705.2065416574478
# * Info * Saved coordinates for step 35400
# * Info * Minimized energy: 1712.7216691970825
# * Info * Saved coordinates for step 35600
# * Info * Minimized energy: 1701.9547920823097
# * Info * Saved coordinates for step 35800
# * Info * Minimized energy: 1707.8036715090275
# * Info * Saved coordinates for step 36000
# * Info * Minimized energy: 1702.1529329419136
# * Info * Saved coordinates for step 36200
# * Info * Minimized energy: 1711.6809030771255
# * Info * Saved coordinates for step 36400
# * Info * Minimized energy: 1714.5423301458359
# * Info * Saved coordinates for step 36600
# * Info * Minimized energy: 1652.5391073226929
# * Info * Saved coordinates for step 36800
# * Info * Minimized energy: 1685.6527101248503
# * Info * Saved coordinates for step 37000
# * Info * Minimized energy: 1665.9618532061577
# * Info * Saved coordinates for step 37200
# * Info * Minimized energy: 1691.8728503584862
# * Info * Saved coordinates for step 37400
# * Info * Minimized energy: 1652.2629514932632
# * Info * Saved coordinates for step 37600
# * Info * Minimized energy: 1722.0363381505013
# * Info * Saved coordinates for step 37800
# * Info * Minimized energy: 1684.640914440155
# * Info * Saved coordinates for step 38000
# * Info * Minimized energy: 1721.2160013914108
# * Info * Saved coordinates for step 38200
# * Info * Minimized energy: 1688.259299814701
# * Info * Saved coordinates for step 38400
# * Info * Minimized energy: 1686.1524686813354
# * Info * Saved coordinates for step 38600
# * Info * Minimized energy: 1676.357992887497
# * Info * Saved coordinates for step 38800
# * Info * Minimized energy: 1676.984979212284
# * Info * Saved coordinates for step 39000
# ...
# * Info * Minimized energy: 1700.3471643924713
# * Info * Saved coordinates for step 87600
# * Info * Minimized energy: 1611.2873622477055
# * Info * Saved coordinates for step 87800
# * Info * Minimized energy: 1618.7752664089203
# * Info * Saved coordinates for step 88000
# * Info * Minimized energy: 1607.3781939148903
# * Info * Saved coordinates for step 88200
# * Info * Minimized energy: 1593.7748094797134
# * Info * Saved coordinates for step 88400
# * Info * Minimized energy: 1647.3080910146236
# * Info * Saved coordinates for step 88600
# * Info * Minimized energy: 1659.53385668993
# * Info * Saved coordinates for step 88800
# * Info * Minimized energy: 1646.095571577549
# * Info * Saved coordinates for step 89000
# * Info * Minimized energy: 1625.265969246626
# * Info * Saved coordinates for step 89200
# * Info * Minimized energy: 1691.4575012028217
# * Info * Saved coordinates for step 89400
# * Info * Minimized energy: 1680.9318456053734
# * Info * Saved coordinates for step 89600
# * Info * Minimized energy: 1687.2953179180622
# * Info * Saved coordinates for step 89800
# * Info * Minimized energy: 1672.8851718306541
# * Info * Saved coordinates for step 90000
# * Info * Minimized energy: 1681.0138677358627
# * Info * Saved coordinates for step 90200
# * Info * Minimized energy: 1690.4942269474268
# * Info * Saved coordinates for step 90400
# * Info * Minimized energy: 1694.8970857858658
# * Info * Saved coordinates for step 90600
# * Info * Minimized energy: 1684.6258816123009
# * Info * Saved coordinates for step 90800
# * Info * Minimized energy: 1678.5032249093056
# * Info * Saved coordinates for step 91000
# * Info * Minimized energy: 1702.9220461249352
# * Info * Saved coordinates for step 91200
# * Info * Minimized energy: 1719.8672563135624
# * Info * Saved coordinates for step 91400
# * Info * Minimized energy: 1691.0856347084045
# * Info * Saved coordinates for step 91600
# * Info * Minimized energy: 1652.6449344158173
# * Info * Saved coordinates for step 91800
# * Info * Minimized energy: 1669.9223607182503
# * Info * Saved coordinates for step 92000
# * Info * Minimized energy: 1664.8440396785736
# * Info * Saved coordinates for step 92200
# * Info * Minimized energy: 1670.8623837828636
# * Info * Saved coordinates for step 92400
# * Info * Minimized energy: 1675.2202185988426
# * Info * Saved coordinates for step 92600
# * Info * Minimized energy: 1702.0703198313713
# * Info * Saved coordinates for step 92800
# * Info * Minimized energy: 1699.4587703943253
# * Info * Saved coordinates for step 93000
# * Info * Minimized energy: 1679.34582875669
# * Info * Saved coordinates for step 93200
# * Info * Minimized energy: 1706.5567854642868
# * Info * Saved coordinates for step 93400
# * Info * Minimized energy: 1700.3006004095078
# * Info * Saved coordinates for step 93600
# * Info * Minimized energy: 1727.7067653536797
# * Info * Saved coordinates for step 93800
# * Info * Minimized energy: 1697.6283324956894
# * Info * Saved coordinates for step 94000
# * Info * Minimized energy: 1699.4569391906261
# * Info * Saved coordinates for step 94200
# * Info * Minimized energy: 1720.4820933640003
# * Info * Saved coordinates for step 94400
# * Info * Minimized energy: 1714.8803001642227
# * Info * Saved coordinates for step 94600
# * Info * Minimized energy: 1665.592309653759
# * Info * Saved coordinates for step 94800
# * Info * Minimized energy: 1659.474917948246
# * Info * Saved coordinates for step 95000
# * Info * Minimized energy: 1675.1881320476532
# * Info * Saved coordinates for step 95200
# * Info * Minimized energy: 1670.4004915952682
# * Info * Saved coordinates for step 95400
# * Info * Minimized energy: 1644.642564535141
# * Info * Saved coordinates for step 95600
# * Info * Minimized energy: 1684.4399007558823
# * Info * Saved coordinates for step 95800
# * Info * Minimized energy: 1713.8398301899433
# * Info * Saved coordinates for step 96000
# * Info * Minimized energy: 1705.100164949894
# * Info * Saved coordinates for step 96200
# * Info * Minimized energy: 1706.1233245134354
# * Info * Saved coordinates for step 96400
# * Info * Minimized energy: 1727.0608378052711
# * Info * Saved coordinates for step 96600
# * Info * Minimized energy: 1695.050343170762
# * Info * Saved coordinates for step 96800
# * Info * Minimized energy: 1691.4665966033936
# * Info * Saved coordinates for step 97000
# * Info * Minimized energy: 1674.441021502018
# * Info * Saved coordinates for step 97200
# * Info * Minimized energy: 1678.5549488663673
# * Info * Saved coordinates for step 97400
# * Info * Minimized energy: 1671.063859730959
# * Info * Saved coordinates for step 97600
# * Info * Minimized energy: 1673.9481180906296
# * Info * Saved coordinates for step 97800
# * Info * Minimized energy: 1682.3033094704151
# * Info * Saved coordinates for step 98000
# * Info * Minimized energy: 1699.8408303260803
# * Info * Saved coordinates for step 98200
# * Info * Minimized energy: 1711.5434383153915
# * Info * Saved coordinates for step 98400
# * Info * Minimized energy: 1693.3696115016937
# * Info * Saved coordinates for step 98600
# * Info * Minimized energy: 1724.8318219780922
# * Info * Saved coordinates for step 98800
# * Info * Minimized energy: 1727.3758478164673
# * Info * Saved coordinates for step 99000
# * Info * Minimized energy: 1708.4179692268372
# * Info * Saved coordinates for step 99200
# * Info * Minimized energy: 1710.6760950684547
# * Info * Saved coordinates for step 99400
# * Info * Minimized energy: 1688.5444876849651
# * Info * Saved coordinates for step 99600
# * Info * Minimized energy: 1716.2369558811188
# * Info * Saved coordinates for step 99800
# * Info * Minimized energy: 1683.2489286065102
# * Info * Saved coordinates for step 100000
# * Info * Conformational sampling completed!
# * Info * Number of conformations: 500
# * Info * Filtering for unique conformers
# * Info *
# Number of unique conformers: 479

# %%
# plot the distribution of the relative energies of the conformers
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(conformers_dict['energies']-np.min(conformers_dict['energies']),
        bins=50, 
        color='darkcyan', 
        alpha=0.7)
plt.xlabel('Relative Energy (kJ/mol)')
plt.ylabel('Number of Conformers')

plt.show()

# %%
opm_dyn.show_conformers(number=5)
# Out:
# * Info *
# Conformation 1: Energy: 1593.775 kJ/mol, Weight: 0.9904
# <div id="3dmolviewer_17734161472072194"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17734161472072194" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17734161472072194 = null;
# var warn = document.getElementById("3dmolwarning_17734161472072194");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17734161472072194 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17734161472072194"),{backgroundColor:"white"});
# viewer_17734161472072194.zoomTo();
# 	viewer_17734161472072194.addModel("394\n\nC              9.764778614044        28.412613868713        -9.551620483398\nC             10.804743766785        27.472822666168        -9.512150883675\nC             11.754990816116        27.440516948700        -8.450557589531\nC             11.607161760330        28.425550460815        -7.407318353653\nC             10.535916090012        29.362149238586        -7.460854053497\nC              9.631155729294        29.353392124176        -8.525753021240\nH              9.061691164970        28.403878211975       -10.374214649200\nH             10.845154523849        26.759696006775       -10.323851108551\nH             12.869633436203        25.640404224396       -10.579454898834\nC             12.814795970917        26.353609561920        -8.499119877815\nC             13.236467838287        25.565583705902        -9.576187729836\nC             14.217368364334        24.608881473541        -9.262207746506\nC             14.605944156647        24.584424495697        -7.917569875717\nS             13.701773881912        25.795750617981        -7.178128957748\nN             12.460592985153        28.514001369476        -6.344562172890\nC             12.323309183121        29.412086009979        -5.312409996986\nC             11.184788942337        30.323278903961        -5.359885692596\nN             10.373222827911        30.276966094971        -6.467683315277\nH             14.599994421005        23.946011066437       -10.024006366730\nH             13.345248699188        22.159843444824        -1.370238363743\nC             13.400110006332        29.328889846802        -4.249734580517\nC             13.788505792618        30.480742454529        -3.515702784061\nC             14.783337116241        30.428638458252        -2.510081827641\nC             15.417528152466        29.199087619781        -2.248148620129\nC             15.074013471603        28.053717613220        -2.976267337799\nC             14.087132215500        28.118097782135        -3.967744410038\nH             15.567604303360        27.111823558807        -2.773613631725\nC             10.728003978729        31.276788711548        -4.272498488426\nC             10.779812335968        30.934157371521        -2.894254624844\nC             10.371540784836        31.838505268097        -1.904988139868\nC              9.892394542694        33.104596138000        -2.267855107784\nC              9.808548688889        33.483800888062        -3.625600934029\nC             10.221046209335        32.563276290894        -4.612953364849\nH             11.133958101273        29.967279434204        -2.570071518421\nH             16.184104681015        29.123291969299        -