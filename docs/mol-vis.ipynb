# %% [markdown]
# # Molecular structure

# %% [markdown]
# In Jupyter notebook, a molecule object can be visualized using the show function.
#
# The `atom_indices` and `atom_labels` options can be used.

# %% [markdown]
# **From a notebook cell**

# %%
import veloxchem as vlx

molecule = vlx.Molecule.read_smiles('C1=CC=C(C=C1)C(=O)O')

molecule.show(atom_indices=True, atom_labels=True)
# Out:
# <div id="3dmolviewer_17767695609295397"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17767695609295397" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17767695609295397 = null;
# var warn = document.getElementById("3dmolwarning_17767695609295397");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17767695609295397 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17767695609295397"),{backgroundColor:"white"});
# viewer_17767695609295397.zoomTo();
# 	viewer_17767695609295397.addModel("15\n\nC             -0.045565000000         1.985755000000        -1.067942000000\nC             -0.785457000000         0.832819000000        -1.340055000000\nC             -0.462960000000        -0.373245000000        -0.709849000000\nC              0.607656000000        -0.435923000000         0.202189000000\nC              1.345759000000         0.731873000000         0.468360000000\nC              1.018698000000         1.935203000000        -0.164832000000\nC              0.954792000000        -1.708185000000         0.872769000000\nO              0.294652000000        -2.755987000000         0.635715000000\nO              2.015608000000        -1.760230000000         1.773446000000\nH             -0.296856000000         2.918155000000        -1.556793000000\nH             -1.610002000000         0.873219000000        -2.040115000000\nH             -1.050442000000        -1.254260000000        -0.936218000000\nH              2.174842000000         0.716984000000         1.164565000000\nH              1.591317000000         2.829401000000         0.045192000000\nH              2.261714000000        -2.626159000000         2.238061000000\n");
# 	viewer_17767695609295397.addLabel("C1",{"position": {"x": -0.045564999999999994, "y": 1.985755, "z": -1.067942}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("C2",{"position": {"x": -0.785457, "y": 0.832819, "z": -1.340055}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("C3",{"position": {"x": -0.46296, "y": -0.373245, "z": -0.7098489999999998}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("C4",{"position": {"x": 0.6076559999999999, "y": -0.43592299999999995, "z": 0.20218899999999998}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("C5",{"position": {"x": 1.345759, "y": 0.731873, "z": 0.46836}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("C6",{"position": {"x": 1.018698, "y": 1.935203, "z": -0.16483199999999998}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("C7",{"position": {"x": 0.954792, "y": -1.708185, "z": 0.872769}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("O8",{"position": {"x": 0.294652, "y": -2.755987, "z": 0.6357149999999999}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("O9",{"position": {"x": 2.015608, "y": -1.76023, "z": 1.7734459999999999}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("H10",{"position": {"x": -0.296856, "y": 2.9181549999999996, "z": -1.556793}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("H11",{"position": {"x": -1.610002, "y": 0.873219, "z": -2.040115}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("H12",{"position": {"x": -1.050442, "y": -1.25426, "z": -0.936218}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("H13",{"position": {"x": 2.174842, "y": 0.716984, "z": 1.164565}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("H14",{"position": {"x": 1.591317, "y": 2.829401, "z": 0.045192}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.addLabel("H15",{"position": {"x": 2.261714, "y": -2.6261589999999995, "z": 2.2380609999999996}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17767695609295397.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17767695609295397.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17767695609295397.zoomTo();
# viewer_17767695609295397.render();
# });
# </script>

# %% [markdown]
# **From an h5 file**

# %%
molecule, basis = vlx.read_molecule_and_basis("../output_files/biphenyl-scf.h5")

molecule.show()
# Out:
# <div id="3dmolviewer_17767695609457405"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17767695609457405" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17767695609457405 = null;
# var warn = document.getElementById("3dmolwarning_17767695609457405");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17767695609457405 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17767695609457405"),{backgroundColor:"white"});
# viewer_17767695609457405.zoomTo();
# 	viewer_17767695609457405.addModel("22\n\nC             -0.723400000000         0.000300000000        -0.000100000000\nC              0.723400000000        -0.000200000000        -0.000100000000\nC             -1.420600000000        -0.958600000000         0.734900000000\nC              1.420600000000         0.734800000000         0.958600000000\nC             -1.421000000000         0.958800000000        -0.735000000000\nC              1.421100000000        -0.735000000000        -0.958800000000\nC             -2.815400000000        -0.958800000000         0.735000000000\nC              2.815500000000         0.735100000000         0.958800000000\nC             -2.815900000000         0.958600000000        -0.734900000000\nC              2.815900000000        -0.734800000000        -0.958600000000\nC             -3.513200000000        -0.000200000000         0.000100000000\nC              3.513100000000         0.000100000000         0.000100000000\nH             -0.892300000000        -1.713000000000         1.313100000000\nH              0.892400000000         1.313200000000         1.713000000000\nH             -0.893100000000         1.713400000000        -1.313400000000\nH              0.893100000000        -1.313400000000        -1.713300000000\nH             -3.358400000000        -1.705400000000         1.307200000000\nH              3.358500000000         1.307400000000         1.705100000000\nH             -3.359300000000         1.704900000000        -1.307000000000\nH              3.359300000000        -1.306900000000        -1.705100000000\nH             -4.599200000000        -0.000400000000         0.000200000000\nH              4.599200000000         0.000300000000         0.000200000000\n");
# 	viewer_17767695609457405.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17767695609457405.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17767695609457405.zoomTo();
# viewer_17767695609457405.render();
# });
# </script>
