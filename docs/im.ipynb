# %% [markdown]
# (sec:im)=
# # Interpolation mechanics
# - Explain what is interpolation mechanics
# - Deriving the Force-Field
# - Running a dynamics

# %% [markdown]
# (sec:im-ff-gen)=
# ## Force field generation
# We define first a VeloxChem Molecule for which the interpolation mechaics force field (IM-MM) will be constructed.

# %%
import veloxchem as vlx
# Initialize the Molecule
molecule_xyz = '''16

C              1.354430000000         0.723890000000         0.062850000000
C              0.075030000000         1.193180000000        -0.131980000000
S             -1.063880000000        -0.076840000000        -0.238910000000
C              0.145050000000        -1.275960000000        -0.023130000000
C              1.392450000000        -0.699780000000         0.133940000000
C             -0.161190000000        -2.684380000000         0.016020000000
C              0.347150000000        -3.612800000000         0.907410000000
C             -0.139800000000        -4.931010000000         0.664450000000
C             -0.992970000000        -4.972470000000        -0.413030000000
S             -1.212210000000        -3.430270000000        -1.117120000000
H              2.219640000000         1.368740000000         0.151510000000
H             -0.248470000000         2.221020000000        -0.218570000000
H              2.299910000000        -1.273800000000         0.280250000000
H              1.028740000000        -3.357480000000         1.709320000000
H              0.125220000000        -5.802850000000         1.250990000000
H             -1.502580000000        -5.833680000000        -0.824080000000
'''


molecule = vlx.Molecule.from_xyz_string(molecule_xyz)
molecule.show(atom_indices=False)
# Out:
# <div id="3dmolviewer_17737401266965253"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17737401266965253" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17737401266965253 = null;
# var warn = document.getElementById("3dmolwarning_17737401266965253");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17737401266965253 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17737401266965253"),{backgroundColor:"white"});
# viewer_17737401266965253.zoomTo();
# 	viewer_17737401266965253.addModel("16\n\nC              1.354430000000         0.723890000000         0.062850000000\nC              0.075030000000         1.193180000000        -0.131980000000\nS             -1.063880000000        -0.076840000000        -0.238910000000\nC              0.145050000000        -1.275960000000        -0.023130000000\nC              1.392450000000        -0.699780000000         0.133940000000\nC             -0.161190000000        -2.684380000000         0.016020000000\nC              0.347150000000        -3.612800000000         0.907410000000\nC             -0.139800000000        -4.931010000000         0.664450000000\nC             -0.992970000000        -4.972470000000        -0.413030000000\nS             -1.212210000000        -3.430270000000        -1.117120000000\nH              2.219640000000         1.368740000000         0.151510000000\nH             -0.248470000000         2.221020000000        -0.218570000000\nH              2.299910000000        -1.273800000000         0.280250000000\nH              1.028740000000        -3.357480000000         1.709320000000\nH              0.125220000000        -5.802850000000         1.250990000000\nH             -1.502580000000        -5.833680000000        -0.824080000000\n");
# 	viewer_17737401266965253.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17737401266965253.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17737401266965253.zoomTo();
# viewer_17737401266965253.render();
# });
# </script>

# %% [markdown]
# We then initialize the QM-Driver determining the underlying quality of the interpolation data.

# %%
# Initialize the basis set and the QM driver
basis_set_label = "def2-svp"
basis = vlx.MolecularBasis.read(molecule, basis_set_label)
qm_driver = vlx.ScfRestrictedDriver()
qm_driver.xcfun = "b3lyp"

# %% [markdown]
# Define dyanmics and interpolation settings which are crucial for the quality in timing of the database. Important variables:
#
#     .desired_point_density -> how many datapoints should the database contain for each conformer.
#     .converged_cycle -> after how many cycles the construction for 1 conformer terminates (1 cycle: 3000 steps without database expansion).
#     .energy_thrsh -> allowed devaition of the IM energy and QM reference calculations.
#
# As this notebook is intended to be a practival example on how to use the IMFroceFieldGenerator but keeping the computational effort at a reasoable level, the shown settings have been used. For production run we recommend using the following settings:
#
#     .nsteps = 50000
#     .snapshots = 10000
#     .desired_point_density = 80
#     .converged_cycle = 5
#     .energy_threshold = 2.0 kcal/mol

# %%
# Initialize the IM force field generator with:
# dihedrals: list of dihedral angles to sample
# sampling_structures: number of structures to sample
# ensemble: NVT or NVE
# temperature: temperature of the ensemble
# nsteps: number of steps to run the dynamics
# snapshots: number of snapshots to save

imffgen_drv = vlx.IMForceFieldGenerator(qm_driver)
imffgen_drv.dihedrals_dict = [((2, 3, 5, 9), 10)]
imffgen_drv.ensemble = 'NVT'
imffgen_drv.temperature = 250
imffgen_drv.nsteps = 10000
imffgen_drv.snapshots = 5000
imffgen_drv.converged_cycle = 3
imffgen_drv.energy_threshold = 2.0
imffgen_drv.desired_point_density = 10
imffgen_drv.nstruc_to_confirm_database_quality = 10
imffgen_drv.minimize = False
# Out:
# IMPORTANT: IM ForceFieldFile is initalized as im_database.h5

# %% [markdown]
# The compute function starts the construction of a new or given database. The construction run ends by confirming the qulity of the database and the result are stored.
#
# Note that here we provide the constructed database ('im_database.h5') as the computational cost of the second derivatives are very demanding.

# %%
# Run the database consruction
imffgen_drv.imforcefieldfile = "im_database.h5"
im_results = imffgen_drv.compute(molecule, basis)
# Out:
# Initial Density {(2, 3, 5, 9): {0.0: 0, 36.0: 0, 72.0: 0, 108.0: 0, 144.0: 0, 180.0: 0, 216.0: 0, 252.0: 0, 288.0: 0, 324.0: 0}}
# Database expansion with point_1
# Database expansion with point_1, point_2
# Database expansion with point_1, point_2, point_3
# Database expansion with point_1, point_2, point_3, point_4
# Database expansion with point_1, point_2, point_3, point_4, point_5
# Database expansion with point_1, point_2, point_3, point_4, point_5, point_6
# Database expansion with point_1, point_2, point_3, point_4, point_5, point_6, point_7
# Database expansion with point_1, point_2, point_3, point_4, point_5, point_6, point_7, point_8
# Database expansion with point_1, point_2, point_3, point_4, point_5, point_6, point_7, point_8, point_9
# Database expansion with point_10, point_1, point_2, point_3, point_4, point_5, point_6, point_7, point_8, point_9
# * Info * Using 6-31G* basis set for RESP charges...
# * Info * Sum of partial charges is not a whole number.
# * Info * Compensating by removing 2.000e-06 from the largest charge.
#
# * Info * Using GAFF (v2.11) parameters.
#          Reference: J. Wang, R. M. Wolf, J. W. Caldwell, P. A. Kollman, D. A. Case, J. Comput. Chem. 2004,
#          25, 1157-1174.
#
# * Info * Updated bond angle 4-6-7 (cd-cd-cc) to 126.500 deg
# * Info * Updated bond angle 5-4-6 (cc-cd-cd) to 126.544 deg
# * Info * Full molecule as QM region
# QM region parameters written to qm_region.xml
# No external MM atoms found in the system
# * Info * System parameters written to qm_region_system.xml
# * Info * System coordinates written to qm_region_system.pdb
# QM/MM Simulation Parameters
# ============================================================
# QM Driver: None
# Ensemble: NVT
# Integration method: LangevinIntegrator
# Temperature: 250 K K
# Friction: 1.0 /ps 1/ps
# Timestep: 0.5 fs fs
# Total simulation time in ns: 0.005
# ============================================================
# current datapoints around the given starting structure 10 1 (2, 3, 5, 9)
#  allowed derivation from the given structure (342.0, 18.0)
#  ---------------------------------------
# Step: 0 / 10000 Time: 0.0 ps
# Potential Energy QM region: -2899550.989515567 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899550.989515567 kJ/mol
# Kinetic Energy: 67.21574032306671 kJ/mol
# Temperature: 336.84147435814816 K
# Total Energy: -2899483.773775244 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 2 / 10000 Time: 0.0 ps
# Potential Energy QM region: -2899548.063748744 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899548.063748744 kJ/mol
# Kinetic Energy: 60.95054078102112 kJ/mol
# Temperature: 305.4443783692135 K
# Total Energy: -2899487.113207963 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 4 / 10000 Time: 0.0 ps
# Potential Energy QM region: -2899539.470512189 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899539.470512189 kJ/mol
# Kinetic Energy: 52.38211318850517 kJ/mol
# Temperature: 262.5050048040065 K
# Total Energy: -2899487.0883990005 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 6 / 10000 Time: 0.0 ps
# Potential Energy QM region: -2899530.8455089233 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899530.8455089233 kJ/mol
# Kinetic Energy: 43.13110363483429 kJ/mol
# Temperature: 216.1449754063917 K
# Total Energy: -2899487.7144052885 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 8 / 10000 Time: 0.0 ps
# Potential Energy QM region: -2899525.4896753747 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899525.4896753747 kJ/mol
# Kinetic Energy: 36.4949734210968 kJ/mol
# Temperature: 182.8890166907085 K
# Total Energy: -2899488.9947019536 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 10 / 10000 Time: 0.01 ps
# Potential Energy QM region: -2899521.8740179557 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899521.8740179557 kJ/mol
# Kinetic Energy: 32.86995017528534 kJ/mol
# Temperature: 164.72276323827637 K
# Total Energy: -2899489.0040677804 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 12 / 10000 Time: 0.01 ps
# Potential Energy QM region: -2899516.8665452506 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899516.8665452506 kJ/mol
# Kinetic Energy: 28.288184598088264 kJ/mol
# Temperature: 141.7619408956436 K
# Total Energy: -2899488.5783606526 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 14 / 10000 Time: 0.01 ps
# Potential Energy QM region: -2899509.1988745076 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899509.1988745076 kJ/mol
# Kinetic Energy: 21.182492718100548 kJ/mol
# Temperature: 106.15284520338949 K
# Total Energy: -2899488.0163817895 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 16 / 10000 Time: 0.01 ps
# Potential Energy QM region: -2899503.6356957536 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899503.6356957536 kJ/mol
# Kinetic Energy: 15.690807901322842 kJ/mol
# Temperature: 78.63210078396298 K
# Total Energy: -2899487.9448878523 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 18 / 10000 Time: 0.01 ps
# Potential Energy QM region: -2899506.114144404 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899506.114144404 kJ/mol
# Kinetic Energy: 18.033056616783142 kJ/mol
# Temperature: 90.36992449663842 K
# Total Energy: -2899488.081087787 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 20 / 10000 Time: 0.01 ps
# Potential Energy QM region: -2899513.167462102 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899513.167462102 kJ/mol
# Kinetic Energy: 25.447712182998657 kJ/mol
# Temperature: 127.52734477911329 K
# Total Energy: -2899487.719749919 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 22 / 10000 Time: 0.01 ps
# Potential Energy QM region: -2899517.2098113587 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2
kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 50 / 10000 Time: 0.03 ps
# Potential Energy QM region: -2899520.786070944 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899520.786070944 kJ/mol
# Kinetic Energy: 33.5713243894279 kJ/mol
# Temperature: 168.23759359249166 K
# Total Energy: -2899487.2147465544 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 52 / 10000 Time: 0.03 ps
# Potential Energy QM region: -2899523.4856132613 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899523.4856132613 kJ/mol
# Kinetic Energy: 35.68261660262942 kJ/mol
# Temperature: 178.81801387020485 K
# Total Energy: -2899487.8029966587 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 54 / 10000 Time: 0.03 ps
# Potential Energy QM region: -2899523.430172675 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899523.430172675 kJ/mol
# Kinetic Energy: 35.622904842719436 kJ/mol
# Temperature: 178.51877745403317 K
# Total Energy: -2899487.807267832 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 56 / 10000 Time: 0.03 ps
# Potential Energy QM region: -2899520.572116185 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899520.572116185 kJ/mol
# Kinetic Energy: 33.070615481585264 kJ/mol
# Temperature: 165.7283669451123 K
# Total Energy: -2899487.5015007034 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 58 / 10000 Time: 0.03 ps
# Potential Energy QM region: -2899519.5078223213 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899519.5078223213 kJ/mol
# Kinetic Energy: 31.517439052462578 kJ/mol
# Temperature: 157.94485915646908 K
# Total Energy: -2899487.990383269 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 60 / 10000 Time: 0.03 ps
# Potential Energy QM region: -2899523.264692064 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899523.264692064 kJ/mol
# Kinetic Energy: 34.99864515662193 kJ/mol
# Temperature: 175.39039484548402 K
# Total Energy: -2899488.2660469073 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 62 / 10000 Time: 0.03 ps
# Potential Energy QM region: -2899527.6190066407 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899527.6190066407 kJ/mol
# Kinetic Energy: 38.53490075469017 kJ/mol
# Temperature: 193.11180271267946 K
# Total Energy: -2899489.084105886 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 64 / 10000 Time: 0.03 ps
# Potential Energy QM region: -2899528.5348232 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899528.5348232 kJ/mol
# Kinetic Energy: 40.47242319583893 kJ/mol
# Temperature: 202.821402168725 K
# Total Energy: -2899488.0624000044 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 66 / 10000 Time: 0.03 ps
# Potential Energy QM region: -2899526.9103199285 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899526.9103199285 kJ/mol
# Kinetic Energy: 39.262326404452324 kJ/mol
# Temperature: 196.75718587998693 K
# Total Energy: -2899487.647993524 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# ############# QM calculation ############
# Delta E 1.0633267892578042 kJ/mol
# Step: 68 / 10000 Time: 0.03 ps
# Potential Energy QM region: -2899525.8571271366 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899525.8571271366 kJ/mol
# Kinetic Energy: 38.27576057612896 kJ/mol
# Temperature: 191.81316106427326 K
# Total Energy: -2899487.5813665604 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 70 / 10000 Time: 0.04 ps
# Potential Energy QM region: -2899526.8700455925 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899526.8700455925 kJ/mol
# Kinetic Energy: 39.20252750813961 kJ/mol
# Temperature: 196.4575127929667 K
# Total Energy: -2899487.6675180844 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 72 / 10000 Time: 0.04 ps
# Potential Energy QM region: -2899529.0503692194 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899529.0503692194 kJ/mol
# Kinetic Energy: 41.6869792342186 kJ/mol
# Temperature: 208.9079652965286 K
# Total Energy: -2899487.363389985 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 3
# Step: 74 / 10000 Time: 0.04 ps
# Potential Energy QM region: -2899529.9203810217 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2
kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899527.467717143 kJ/mol
# Kinetic Energy: 49.50707630813122 kJ/mol
# Temperature: 248.09719411912033 K
# Total Energy: -2899477.9606408346 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 2
# Step: 2320 / 10000 Time: 1.16 ps
# Potential Energy QM region: -2899526.1835300745 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899526.1835300745 kJ/mol
# Kinetic Energy: 47.91519433259964 kJ/mol
# Temperature: 240.1197193629849 K
# Total Energy: -2899478.268335742 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 2
# Step: 2322 / 10000 Time: 1.16 ps
# Potential Energy QM region: -2899528.977523048 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899528.977523048 kJ/mol
# Kinetic Energy: 50.40078520774841 kJ/mol
# Temperature: 252.5758805391038 K
# Total Energy: -2899478.57673784 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 2
# Step: 2324 / 10000 Time: 1.16 ps
# Potential Energy QM region: -2899534.5803404767 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899534.5803404767 kJ/mol
# Kinetic Energy: 57.0401616692543 kJ/mol
# Temperature: 285.84810733246024 K
# Total Energy: -2899477.5401788075 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 2
# Step: 2326 / 10000 Time: 1.16 ps
# Potential Energy QM region: -2899537.392732186 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899537.392732186 kJ/mol
# Kinetic Energy: 59.01069071888924 kJ/mol
# Temperature: 295.7231143941143 K
# Total Energy: -2899478.382041467 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 2
# Step: 2328 / 10000 Time: 1.16 ps
# Potential Energy QM region: -2899534.4540542183 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899534.4540542183 kJ/mol
# Kinetic Energy: 56.27552616596222 kJ/mol
# Temperature: 282.0162526353678 K
# Total Energy: -2899478.1785280523 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 2
# Step: 2330 / 10000 Time: 1.17 ps
# Potential Energy QM region: -2899528.4933309434 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899528.4933309434 kJ/mol
# Kinetic Energy: 49.39515110850334 kJ/mol
# Temperature: 247.53629797962566 K
# Total Energy: -2899479.098179835 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 2
# Step: 2332 / 10000 Time: 1.17 ps
# Potential Energy QM region: -2899525.278503996 kJ/mol
# Potential Energy MM region: 0.0 kJ/mol
# QM/MM Interaction Energy: 0.0 kJ/mol
# Total Potential Energy: -2899525.278503996 kJ/mol
# Kinetic Energy: 46.518214255571365 kJ/mol
# Temperature: 233.11896587081995 K
# Total Energy: -2899478.7602897403 kJ/mol
# ------------------------------------------------------------
# Current Density 1 --> 10 2
# ############# QM calculation ############
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Run the database consruction
#       2 imffgen_drv.imforcefieldfile = "im_database.h5"
# ----> 3 im_results = imffgen_drv.compute(molecule, basis)
#
# File ~/miniconda3/envs/vlx-github/lib/python3.12/site-packages/veloxchem/imforcefieldgenerator.py:387, in IMForceFieldGenerator.compute(self, molecule, basis)
#     385     im_database_driver.allowed_molecule_deviation = self.allowed_deviation[key][current_dihedral_angle]
#     386 im_database_driver.update_settings(self.dynamics_settings, self.interpolation_settings)
# --> 387 im_database_driver.run_qmmm()
#     388 # individual impes run objects
#     389 self.qm_energies.extend(im_database_driver.qm_potentials)
#
# File ~/miniconda3/envs/vlx-github/lib/python3.12/site-packages/veloxchem/imdatabasepointcollecter.py:788, in IMDatabasePointCollecter.run_qmmm(self)
#     784 self.step = 0
#     786 for step in range(self.nsteps):
# --> 788     self.update_forces(self.simulation.context)
#     790     # Potential energies
#     791     # QM region
#     792     qm = self.get_qm_potential_energy()
#
# File ~/miniconda3/envs/vlx-github/lib/python3.12/site-packages/veloxchem/imdatabasepointcollecter.py:1746, in IMDatabasePointCollecter.update_forces(self, context)
#    1744 self.point_checker += 1
#    1745 if self.add_a_point == True and self.step > self.collect_qm_points or self.check_a_point == True and self.step > self.collect_qm_points:
# -> 1746     self.point_correlation_check(new_molecule)
#    1747 if self.point_checker == 0:
#    1749     self.point_checker += 1
#
# File ~/miniconda3/envs/vlx-github/lib/python3.12/site-packages/veloxchem/imdatabasepointcollecter.py:1836, in IMDatabasePointCollecter.point_correlation_check(self, molecule)
#    1834 print('############# QM calculation ############')
#    1835 current_basis = MolecularBasis.read(molecule, self.basis_set_label)
# -> 1836 qm_energy, scf_tensors = self.compute_energy(molecule, current_basis)
#    1838 energy_difference = (abs(qm_energy[0] - self.impes_driver.impes_coordinate.energy))
#    1839 print(f'Delta E {energy_difference * hartree_in_kcalpermol() * 4.1840} kJ/mol')
#
# File ~/miniconda3/envs/vlx-github/lib/python3.12/site-packages/veloxchem/imdatabasepointcollecter.py:1973, in IMDatabasePointCollecter.compute_energy(self, molecule, basis)
#    1971 if isinstance(self.qm_driver, ScfRestrictedDriver):
#    1972     self.qm_driver.ostream.mute()
# -> 1973     scf_tensors = self.qm_driver.compute(molecule, basis)
#    1974     qm_energy = self.qm_driver.scf_energy
#    1975     qm_energy = np.array([qm_energy])
#
# File ~/miniconda3/envs/vlx-github/lib/python3.12/site-packages/veloxchem/scfdriver.py:681, in ScfDriver.compute(self, molecule, ao_basis, min_basis)
#     678 grid_drv.set_level(grid_level)
#     680 grid_t0 = tm.time()
# --> 681 self._mol_grid = grid_drv.generate(molecule, self._xcfun_ldstaging)
#     682 n_grid_points = self._mol_grid.number_of_points()
#     684 if self.print_level > 1:
#
# File ~/miniconda3/envs/vlx-github/lib/python3.12/site-packages/veloxchem/griddriver.py:98, in GridDriver.generate(self, molecule, max_points_per_box, verbose)
#      87 def generate(self, molecule, max_points_per_box=None, verbose=False):
#      88     """
#      89     Generates molecular grid for molecule.
#      90
#    (...)
#      95         The molecular grid.
#      96     """
# ---> 98     local_grid = self._grid_drv._generate_local_grid(
#      99         molecule, self.rank, self.nodes)
#     101     grid_np_arrays = self.comm.allgather(local_grid.grid_to_numpy())
#     102     grid_np_arrays = [arr for arr in grid_np_arrays if arr.size > 0]
#
# KeyboardInterrupt:

# %%
ff_gen = vlx.MMForceFieldGenerator()
ff_gen.create_topology(molecule)

# %% [markdown]
# To use the constructed IM force field one has to initialize the InterpolationDriver() with user-defined settings (recommended). The current implementation is restricted to well seperated IM and MM regions and is not yet included into a linking atom framework.

# %%
z_matrix = imffgen_drv.define_z_matrix(molecule)
im_driver = vlx.InterpolationDriver(z_matrix)
interpolation_settings = { 'interpolation_type':'shepard', 
                            'exponent_p':'2',
                            'exponent_q':'2', 
                            'confidence_radius':'0.5',
                            'imforcefieldfile':'im_database.h5'}
im_driver.update_settings(interpolation_settings)

openmmdyn = vlx.OpenMMDynamics()
openmmdyn.create_system_from_molecule(molecule, ff_gen, qm_atoms='all')
openmmdyn.run_qmmm(im_driver, im_driver)
